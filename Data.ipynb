# %% [markdown]
# # Data

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import matplotlib.pylab

# %pylab inline
pylab.rcParams['figure.figsize'] = (15, 8)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("MLTollsStackOverflow.csv", index_col=["month"])
df.head()
# Out:
#         nltk  spacy  stanford-nlp  python   r  numpy  scipy  matlab  \
# month
# 09-Jan     0      0             0     631   8      6      2      19
# 09-Feb     1      0             0     633   9      7      3      27
# 09-Mar     0      0             0     766   4      4      2      24
# 09-Apr     0      0             0     768  12      6      3      32
# 09-May     1      0             0    1003   2      7      2      42
#
#         machine-learning  pandas  ...  Plato  Sympy  Flair  stanford-nlp.1  \
# month                             ...
# 09-Jan                 8       0  ...      0      1      0               0
# 09-Feb                 4       0  ...      0      0      0               0
# 09-Mar                 3       0  ...      0      0      0               0
# 09-Apr                10       0  ...      0      0      0               0
# 09-May                 7       0  ...      0      0      0               0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 132 entries, 09-Jan to 19-Dec
# Data columns (total 81 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   nltk                   132 non-null    int64
#  1   spacy                  132 non-null    int64
#  2   stanford-nlp           132 non-null    int64
#  3   python                 132 non-null    int64
#  4   r                      132 non-null    int64
#  5   numpy                  132 non-null    int64
#  6   scipy                  132 non-null    int64
#  7   matlab                 132 non-null    int64
#  8   machine-learning       132 non-null    int64
#  9   pandas                 132 non-null    int64
#  10  pytorch                132 non-null    int64
#  11  keras                  132 non-null    int64
#  12  nlp                    132 non-null    int64
#  13  apache-spark           132 non-null    int64
#  14  hadoop                 132 non-null    int64
# ...

# %%
df.index
# Out:
# Index(['09-Jan', '09-Feb', '09-Mar', '09-Apr', '09-May', '09-Jun', '09-Jul',
#        '09-Aug', '09-Sep', '09-Oct',
#        ...
#        '19-Mar', '19-Apr', '19-May', '19-Jun', '19-Jul', '19-Aug', '19-Sep',
#        '19-Oct', '19-Nov', '19-Dec'],
#       dtype='object', name='month', length=132)

# %%
df.head()
# Out:
#         nltk  spacy  stanford-nlp  python   r  numpy  scipy  matlab  \
# month
# 09-Jan     0      0             0     631   8      6      2      19
# 09-Feb     1      0             0     633   9      7      3      27
# 09-Mar     0      0             0     766   4      4      2      24
# 09-Apr     0      0             0     768  12      6      3      32
# 09-May     1      0             0    1003   2      7      2      42
#
#         machine-learning  pandas  ...  Plato  Sympy  Flair  stanford-nlp.1  \
# month                             ...
# 09-Jan                 8       0  ...      0      1      0               0
# 09-Feb                 4       0  ...      0      0      0               0
# 09-Mar                 3       0  ...      0      0      0               0
# 09-Apr                10       0  ...      0      0      0               0
# 09-May                 7       0  ...      0      0      0               0
#
# ...

# %%
# Add a Day component to the datetime index #
df.index = df.index + "-01"

# %%
df.index
# Out:
# Index(['09-Jan-01', '09-Feb-01', '09-Mar-01', '09-Apr-01', '09-May-01',
#        '09-Jun-01', '09-Jul-01', '09-Aug-01', '09-Sep-01', '09-Oct-01',
#        ...
#        '19-Mar-01', '19-Apr-01', '19-May-01', '19-Jun-01', '19-Jul-01',
#        '19-Aug-01', '19-Sep-01', '19-Oct-01', '19-Nov-01', '19-Dec-01'],
#       dtype='object', name='month', length=132)

# %%
# convert Index to datatime and save as df_datetime #
df_datetime = pd.to_datetime(df.index,yearfirst=True)
df_datetime
# Out:
# DatetimeIndex(['2009-01-01', '2009-02-01', '2009-03-01', '2009-04-01',
#                '2009-05-01', '2009-06-01', '2009-07-01', '2009-08-01',
#                '2009-09-01', '2009-10-01',
#                ...
#                '2019-03-01', '2019-04-01', '2019-05-01', '2019-06-01',
#                '2019-07-01', '2019-08-01', '2019-09-01', '2019-10-01',
#                '2019-11-01', '2019-12-01'],
#               dtype='datetime64[ns]', name='month', length=132, freq=None)

# %%
# set df.index to datatime index #
df.index = df_datetime

# %%
df.index
# Out:
# DatetimeIndex(['2009-01-01', '2009-02-01', '2009-03-01', '2009-04-01',
#                '2009-05-01', '2009-06-01', '2009-07-01', '2009-08-01',
#                '2009-09-01', '2009-10-01',
#                ...
#                '2019-03-01', '2019-04-01', '2019-05-01', '2019-06-01',
#                '2019-07-01', '2019-08-01', '2019-09-01', '2019-10-01',
#                '2019-11-01', '2019-12-01'],
#               dtype='datetime64[ns]', name='month', length=132, freq=None)

# %%
df.head()
# Out:
#             nltk  spacy  stanford-nlp  python   r  numpy  scipy  matlab  \
# month
# 2009-01-01     0      0             0     631   8      6      2      19
# 2009-02-01     1      0             0     633   9      7      3      27
# 2009-03-01     0      0             0     766   4      4      2      24
# 2009-04-01     0      0             0     768  12      6      3      32
# 2009-05-01     1      0             0    1003   2      7      2      42
#
#             machine-learning  pandas  ...  Plato  Sympy  Flair  \
# month                                 ...
# 2009-01-01                 8       0  ...      0      1      0
# 2009-02-01                 4       0  ...      0      0      0
# 2009-03-01                 3       0  ...      0      0      0
# 2009-04-01                10       0  ...      0      0      0
# 2009-05-01                 7       0  ...      0      0      0
#
#             stanford-nlp.1  pyqt  Nolearn  Lasagne  OCR  Apache-spark-mlib  \
# month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 132 entries, 2009-01-01 to 2019-12-01
# Data columns (total 81 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   nltk                   132 non-null    int64
#  1   spacy                  132 non-null    int64
#  2   stanford-nlp           132 non-null    int64
#  3   python                 132 non-null    int64
#  4   r                      132 non-null    int64
#  5   numpy                  132 non-null    int64
#  6   scipy                  132 non-null    int64
#  7   matlab                 132 non-null    int64
#  8   machine-learning       132 non-null    int64
#  9   pandas                 132 non-null    int64
#  10  pytorch                132 non-null    int64
#  11  keras                  132 non-null    int64
#  12  nlp                    132 non-null    int64
#  13  apache-spark           132 non-null    int64
# ...

# %%
df.columns
# Out:
# Index(['nltk', 'spacy', 'stanford-nlp', 'python', 'r', 'numpy', 'scipy',
#        'matlab', 'machine-learning', 'pandas', 'pytorch', 'keras', 'nlp',
#        'apache-spark', 'hadoop', 'pyspark', 'python-3.x', 'tensorflow',
#        'deep-learning', 'neural-network', 'lstm', 'time-series', 'pillow',
#        'rasa', 'opencv', 'pipenv', 'seaborn', 'Dask', 'jupyter', 'AllenNLP',
#        'Theano', 'plotly', 'scikit-learn', 'BeautifulSoup', 'scrapy', 'Gensim',
#        'FastText', 'Pydot', 'Pybrain', 'Pytil', 'Pygame', 'Colab', 'Shogun',
#        'KNIME', 'Apache', 'Gunicorn', 'Pygtk', 'Weka', 'Conda', 'Ray',
#        'matlab.1', 'accord.net', 'regression', 'classification', 'correlation',
#        'cluster-analysis', 'H2o', 'Mallet', 'Numba', 'Tableau', 'Trifacta',
#        'PyArrow', 'Rasterio', 'Orange3', 'PyMC3', 'Opennn', 'Oryx', 'Istio',
#        'Venes', 'Plotnine', 'Gluon', 'Plato', 'Sympy', 'Flair',
#        'stanford-nlp.1', 'pyqt', 'Nolearn', 'Lasagne', 'OCR',
# ...

# %%
# list of frameworks I want to forecast #
frameworks_to_forcast = ['nltk', 'stanford-nlp', 'python', 'r', 'numpy', 'scipy',
        'pandas', 'pytorch', 'keras', 'nlp',
        'hadoop', 'python-3.x', 'tensorflow',
       'lstm', 'seaborn',
       'plotly', 'scikit-learn', 'BeautifulSoup']

# %%
len(frameworks_to_forcast)
# Out:
# 18

# %%
# new df with only desired frameworks #
df = df[frameworks_to_forcast]
df.head()
# Out:
#             nltk  stanford-nlp  python     r  numpy  scipy  pandas  pytorch  \
# month
# 2017-01-01    56            49   14388  3519    802    138    1540        4
# 2017-02-01    77            51   14901  3706    931    175    1567        3
# 2017-03-01    86            56   17280  4637   1092    219    1989       14
# 2017-04-01    94            62   15752  4280   1031    229    1840       23
# 2017-05-01    82            61   16291  4349    965    191    1923       25
#
#             keras  nlp  hadoop  python-3.x  tensorflow  lstm  seaborn  plotly  \
# month
# 2017-01-01    209  125     483        2033         779    31       45      72
# 2017-02-01    241  149     537        2218         963    45       48      93
# 2017-03-01    366  161     602        2722        1127    80       62     120
# 2017-04-01    323  158     537        2397        1043    62       64     100
# 2017-05-01    382  177     493        2514        1093    59       55      85
#
# ...

# %%
df["2017"]
# Out:
# <ipython-input-105-a07d3120be54>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df["2017"]
#             nltk  stanford-nlp  python     r  numpy  scipy  pandas  pytorch  \
# month
# 2017-01-01    56            49   14388  3519    802    138    1540        4
# 2017-02-01    77            51   14901  3706    931    175    1567        3
# 2017-03-01    86            56   17280  4637   1092    219    1989       14
# 2017-04-01    94            62   15752  4280   1031    229    1840       23
# 2017-05-01    82            61   16291  4349    965    191    1923       25
# 2017-06-01    87            45   16173  4490    961    195    1986       55
# 2017-07-01    83            41   17064  4611   1022    177    2084       34
# 2017-08-01    93            46   17472  5051   1020    185    2170       35
# ...

# %%
# df as of 2017 #
df = df.loc["2017":,df.columns]
df
# Out:
#             nltk  stanford-nlp  python     r  numpy  scipy  pandas  pytorch  \
# month
# 2017-01-01    56            49   14388  3519    802    138    1540        4
# 2017-02-01    77            51   14901  3706    931    175    1567        3
# 2017-03-01    86            56   17280  4637   1092    219    1989       14
# 2017-04-01    94            62   15752  4280   1031    229    1840       23
# 2017-05-01    82            61   16291  4349    965    191    1923       25
# 2017-06-01    87            45   16173  4490    961    195    1986       55
# 2017-07-01    83            41   17064  4611   1022    177    2084       34
# 2017-08-01    93            46   17472  5051   1020    185    2170       35
# 2017-09-01    80            48   16949  4641    963    153    2043       41
# 2017-10-01    79            35   18735  5053   1174    210    2305       49
# 2017-11-01    66            46   18935  5117   1156    223    2289       87
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 36 entries, 2017-01-01 to 2019-12-01
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   nltk           36 non-null     int64
#  1   stanford-nlp   36 non-null     int64
#  2   python         36 non-null     int64
#  3   r              36 non-null     int64
#  4   numpy          36 non-null     int64
#  5   scipy          36 non-null     int64
#  6   pandas         36 non-null     int64
#  7   pytorch        36 non-null     int64
#  8   keras          36 non-null     int64
#  9   nlp            36 non-null     int64
#  10  hadoop         36 non-null     int64
#  11  python-3.x     36 non-null     int64
#  12  tensorflow     36 non-null     int64
#  13  lstm           36 non-null     int64
#  14  seaborn        36 non-null     int64
#  15  plotly         36 non-null     int64
#  16  scikit-learn   36 non-null     int64
# ...

# %%
df.tail()
# Out:
#             nltk  stanford-nlp  python     r  numpy  scipy  pandas  pytorch  \
# month
# 2019-08-01    57            24   20257  4486   1111    212    3675      253
# 2019-09-01    54            16   19207  4474   1020    135    3298      260
# 2019-10-01    73            27   23414  5138   1310    188    4098      300
# 2019-11-01    72            14   23602  4883   1297    199    3873      332
# 2019-12-01    82            13   20058  4150   1118    159    3519      343
#
#             keras  nlp  hadoop  python-3.x  tensorflow  lstm  seaborn  plotly  \
# month
# 2019-08-01    889  237     216        6133        1332   112      119     137
# 2019-09-01    786  207     207        5748        1217    93       90     139
# 2019-10-01    929  272     260        6621        1468   131      130     174
# 2019-11-01    902  270     212        6151        1513   129      133     169
# 2019-12-01    834  242     157        5200        1392   137      112     156
#
# ...

# %%
plt.plot(df["r"])

# %%
df
# Out:
#             nltk  stanford-nlp  python     r  numpy  scipy  pandas  pytorch  \
# month
# 2017-01-01    56            49   14388  3519    802    138    1540        4
# 2017-02-01    77            51   14901  3706    931    175    1567        3
# 2017-03-01    86            56   17280  4637   1092    219    1989       14
# 2017-04-01    94            62   15752  4280   1031    229    1840       23
# 2017-05-01    82            61   16291  4349    965    191    1923       25
# 2017-06-01    87            45   16173  4490    961    195    1986       55
# 2017-07-01    83            41   17064  4611   1022    177    2084       34
# 2017-08-01    93            46   17472  5051   1020    185    2170       35
# 2017-09-01    80            48   16949  4641    963    153    2043       41
# 2017-10-01    79            35   18735  5053   1174    210    2305       49
# 2017-11-01    66            46   18935  5117   1156    223    2289       87
# ...

# %%
# save df #
df.to_csv("FrameworkData.csv")
